# %%
################################# input parameters
cur_dir = 'C:/Users/EpicG/Documents/Python Scripts/webscraping/'
number_tweets = 2000
#################################

# %%
import os
# Use tweepy api for authentication 
from configparser import ConfigParser
config = ConfigParser()
config.read('C:/Users/EpicG/Documents/Python Scripts/webscraping/cfg/sample.cfg')
# Out:
# ['C:/Users/EpicG/Documents/Python Scripts/webscraping/cfg/sample.cfg']

# %%
# Create an Authentication Handler
import tweepy
auth = tweepy.OAuthHandler(config.get('twitter', 'consumer_key'), config.get('twitter', 'consumer_secret'))
auth.set_access_token(config.get('twitter','access_token'), config.get('twitter','access_token_secret'))
api = tweepy.API(auth)

# %%
# search tweets for keywords
trump_tweets = api.search(q="Trump", count=number_tweets, show_user=False)
biden_tweets = api.search(q="Biden",count=number_tweets, show_user=False)

# %%
for tweet in trump_tweets:
    print(tweet.text)
# Out:
# RT @sgf125: @mmpadellan @John_the_L I listened to an interview w/Gary Kasparov on Stay Tuned with Preet. He said if you keep turning a corn…
# @CNN Please Florida, Vote Democrat so we have a President Biden who will not cancel Social Security and Medicare! T… https://t.co/Xpb37tt3J9
# RT @enes69: @BrettFavre @realDonaldTrump How come Trump voters do not know or do not care that he is fighting to take away their healthcare…
# RT @MSNBC: “You’re watching the metamorphosis of Texas,” Julián Castro says, discussing the possibility of Texas turning into a blue state.…
# RT @voxdotcom: President Trump has repeatedly said that he's "the least racist person that you've ever encountered."
#
# His actual record tel…
# RT @kayleighmcenany: The Liberal Democrat Governor of Minnesota tried to shut us down by only allowing 250 inside President @realDonaldTrum…
# RT @glennkirschner2: Video dropping shortly: per NYT, Trump and two Attorneys General corruptly try to use the DOJ to kill an investigation…
# RT @JackPosobiec: Trump was angry at what Keith Ellison did. Only let 250 people in. Cut his rally short in MN, then walked off stage over…
# RT @KaivanShroff: NEW: 450 donors who maxed out to Trump in 2016 have not given a penny this go around.
#
# A major sign Trump has alienated…
# RT @Emanate828: @MeidasTouch Stay Woke ... Stay Focused...Vote...Repudiate trump...Eradicate trumpism!!! ✊✊✊✊✊✊🌊🌊🌊🌊🌊🌊🌊
# @realDonaldTrump (WP) Trump's “herd immunity strategy" is to let virus burn through the population, increasing the… https://t.co/A0MXSl7G9T
# RT @htommy998: @RepAdamSchiff No country allowed 4-year proved liar Adam Schiff to stay in Congress, but US did. Trump is the only hope of…
# @atrupar That was worth the taxpayers paying for them to fuel up Air Force One and pay to fly Trump and his secret service and staff around.
# @AngrierWHStaff @DHowser9 I'm hoping W is staying silent now so if the vote is obviously a Biden win &amp; Trump uses t… https://t.co/dmOWqcg6fv
# @RoryDoesPhonics @hollandcourtney The question is if @thedemocrats in Clark hate Trump so much that they want to go… https://t.co/k7FaTZXpX6
# RT @nypost: Trump greets throngs of fans outside Minnesota rally after state allows just 250 seats https://t.co/S5CT67pkIP https://t.co/lA2…
# RT @CarrieSweet2017: @blakehounshell @kyledcheney Of course he is. Trump must have his adulation fix.
# RT @ShutUpAmanda: Trump: “I brought back ‘Merry Christmas.”
#
# Melania: “Who gives a fuck about Christmas”
#
# It checks out.
# %%
########### build library for stopwrods, positive words, and negative words

# punctuation from string library
import re
from collections import Counter

with open(cur_dir + 'stopwords.txt') as inputfile:
    for line in inputfile:
        stopwords = filter(None, (line.rstrip() for line in inputfile))

#stop = open(cur_dir + "stopwords.txt").read()
#stopwords = stop.split('\n')

 # positive words from: http://www.unc.edu/~ncaren/haphazard/positive.txt
positive_words = open(cur_dir + 'positive.txt').read()
positive = positive_words.split('\n')

# negative words from: http://www.unc.edu/~ncaren/haphazard/negative.txt
negative_words = open(cur_dir + 'negative.txt').read()
negative = negative_words.split('\n')

########### function for preprocessing
#import nltk
from string import punctuation

def turn_to_words(input_list):
    text = ' '.join(input_list)  # merge list of strings into a single big string, separated by ' '
    
    for p in list(punctuation): # remove punctuation
        text = text.replace(p,' ')
        
    #for p in list(stopwords): # remove stopwords
    #    text = text.replace(p,' ')
    
    text = text.lower() # to lowercase
    text = text.split() # turn into words
    
    return text

# %%
#for tweet in Trump_tweets:

mylist = []
for tweet in trump_tweets:
    mylist.append(tweet.text) # create a list of tweets (string)

words = turn_to_words(mylist) # create list of words out of all the tweets (remove punctuation + lowercase)

sentiment = [];
for word in words:
    if word in list(positive) or word in list(negative):
        sentiment.append(word)  # create a list of sentiment words

#print(sentiment)

sentiment_counts = Counter(sentiment)
ten_common = sentiment_counts.most_common(10) # 10 most common sentiment words
                                                                                                                

ten_common_list = []
for i in ten_common:
    ten_common_list.append(i[0]) # extract words from each tuple, and make them into a list

pos = 0
neg = 0
for word in ten_common_list:
    if word in positive:
        pos = pos + 1
    if word in negative:
        neg = neg + 1
print(ten_common)
print ("TRUMP: positive words: " + str(pos) + " negative words: " + str(neg))
x=(pos-neg)/10.0
print ("TRUMP's Average Sentiment Value: " + str(float("{0:.2f}".format(x))))
# Out:
# [('just', 9), ('will', 5), ('virus', 3), ('liberal', 2), ('down', 2), ('low', 2), ('accusing', 2), ('dying', 2), ('deadly', 2), ('disease', 2)]
# TRUMP: positive words: 3 negative words: 7
# TRUMP's Average Sentiment Value: -0.4

# %%
#for tweet in Biden_tweets:

mylist = []
for tweet in biden_tweets:
    mylist.append(tweet.text) # create a list of tweets (string)

words = turn_to_words(mylist) # create list of words out of all the tweets (remove punctuation + lowercase)

sentiment = [];
for word in words:
    if word in list(positive) or word in list(negative):
        sentiment.append(word)  # create a list of sentiment words

#print(sentiment)

sentiment_counts = Counter(sentiment)
ten_common = sentiment_counts.most_common(10) # 10 most common sentiment words


ten_common_list = []
for i in ten_common:
    ten_common_list.append(i[0]) # extract words from each tuple, and make them into a list

pos = 0
neg = 0
for word in ten_common_list:
    if word in positive:
        pos = pos + 1
    if word in negative:
        neg = neg + 1
print(ten_common)
print ("BIDEN: positive words: " + str(pos) + " negative words: " + str(neg))
x=(pos-neg)/10.0
print ("BIDEN's Average Sentiment Value: " + str(float("{0:.2f}".format(x))))
# Out:
# [('will', 10), ('down', 7), ('just', 3), ('white', 3), ('need', 3), ('crime', 3), ('even', 2), ('prisoner', 2), ('dictator', 2), ('praising', 2)]
# BIDEN: positive words: 5 negative words: 5
# BIDEN's Average Sentiment Value: 0.0
