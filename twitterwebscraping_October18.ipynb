# %%
################################# input parameters
cur_dir = 'C:/Users/EpicG/Documents/Python Scripts/webscraping/'
number_tweets = 2000
#################################

# %%
import os
# Use tweepy api for authentication 
from configparser import ConfigParser
config = ConfigParser()
config.read('C:/Users/EpicG/Documents/Python Scripts/webscraping/cfg/sample.cfg')
# Out:
# ['C:/Users/EpicG/Documents/Python Scripts/webscraping/cfg/sample.cfg']

# %%
# Create an Authentication Handler
import tweepy
auth = tweepy.OAuthHandler(config.get('twitter', 'consumer_key'), config.get('twitter', 'consumer_secret'))
auth.set_access_token(config.get('twitter','access_token'), config.get('twitter','access_token_secret'))
api = tweepy.API(auth)

# %%
# search tweets for keywords
trump_tweets = api.search(q="Trump", count=number_tweets, show_user=False)
biden_tweets = api.search(q="Biden",count=number_tweets, show_user=False)

# %%
for tweet in trump_tweets:
    print(tweet.text)
# Out:
# RT @Ek7_PRN: If President Trump visited your neighborhood, would you come out to greet him? 🇺🇸 Yes or no?
# RT @rick57777123: A quick edit from today’s Trump Rally in Beverly Hills.
#
# All handheld iPhone 11 Pro Max footage. Check it out! https://t…
# RT @cwebbonline: While Trump is holding ego-boosting #SuperSpreaderEvents Biden is having a safe car rally and it looks like fun. 😎
#
# Wish I…
# RT @Baligubadle1: Matt Gaetz: Joe Biden has dementia
#
# Trump in Michigan: Thank you, Minnesota
# RT @tonyposnanski: Oh god I hate Lara Trump.
# RT @SenKamalaHarris: Trump said that overturning Roe v. Wade will “happen automatically, in my opinion, because I am putting pro-life justi…
# RT @LarryTenney: @CACoastBlue @KMResistInOC They are Pro Armenian supporters!
#
# I'm told there are LOTS of Anti-Trump 🖕🏻GOP @MichelleSteelCA…
# RT @TheRickWilson: "I secretly opposed Trump."
# "I fought against the worst excesses."
# "You won't believe what I stopped him from doing."
# "I…
# RT @thebr0keb0i: If QAnon was really against pedophilia, they wouldn't be supporting Donald Trump the pedophile.
# RT @AlpidioAlonsoG: Denunciamos las maniobras groseras e ilegales de la maquinaria mediática ultraderechista de Miami y del propio gobierno…
# RT @GeorgeTakei: Trump still has a statistically significant chance of pulling off an upset. That number needs to be as close to zero as we…
# RT @RealCandaceO: You need but look at the lines and packed arenas at Trump rallies to determine that he is winning by a landslide.
#
# The D…
# RT @candies2639: Black police officers break from unions over Trump endorsements https://t.co/QFcdLpUu53
# RT @RJC: Reform Rabbi Cary Kozberg:
#
# "I’m proud to be a Republican, I’m proud to support President Trump, and I implore more of my rabbinic…
# RT @CREWcrew: A former Assistant US attorney is “fleeing” DOJ primarily because of Attorney General Barr’s conduct and “obedience” to Trump…
# RT @ElieNYC: And here we go...the ELITE INDUSTRIAL COMPLEX really wants Trump to get away with it all. “Look forward not backwards.”
#
# This…
# RT @TeaPainUSA: It will be a joyful day when these dregs are done and gone.
# https://t.co/KwpQDaSVvX
# RT @duty2warn: “Dammit, Minnesota, you better vote for me," Trump said to his supporters yesterday. He was in Michigan.
# RT @dukewindsor388: My 40th high-school reunion was postponed because of COVID-19, which is weird because 99% of my graduating class doesn'…
# RT @realDonaldTrump: Corrupt politician Joe Biden makes Crooked Hillary look like an amateur!
# This is a tragedy brought on by the greed of Biden.  Noem argues Hunter Biden story 'does grave damage' to former v… https://t.co/EsJGrd5H17
# RT @DonaldJTrumpJr: Just so we’re clear:
#
# Three days ago, Fox News reported that Joe Biden was identified as a FINANCIAL BENEFICIARY in a d…
# RT @RealJamesWoods: So many of those young people imprisoned for minor drug charges, their lives forever ruined by Joe Biden’s racist “crim…
# RT @Slapout4: I got 18 registrations, friends, n family, now voting Biden, ain't much but I'm giving it my all.
# RT @RealCandaceO: You need but look at the lines and packed arenas at Trump rallies to determine that he is winning by a landslide.
#
# The D…
# RT @PalmerReport: Clear sign that the phony Hunter Biden laptop scandal has flopped: the Kremlin now has its puppet Ron Johnson claiming th…
# RT @CapehartJ: Imma just say it: not a fan of Jim Carey's Joe Biden....
# RT @TrumpWarRoom: Even the Biden campaign has not denied that the emails exposing the Biden family's corruption are real.
#
# Biden surrogate:…
# RT @realDonaldTrump: Corrupt politician Joe Biden makes Crooked Hillary look like an amateur!
# RT @realDonaldTrump: Corrupt politician Joe Biden makes Crooked Hillary look like an amateur!
# US spies say the Hunter Biden email controversy shows how 'exploitable' and 'grotesquely vulnerable' Trump and Giul… https://t.co/aONU3nuNpm
# RT @IamNurseTrish: My elderly neighbor thanked me for putting out my signs. She said she was too afraid to put Biden signs out because trum…
# RT @StephenKing: Biden=Science, rationality, facts
# Trump=Superstition, rumors, conspiracy theories
# shouldn’t be a hard choice.
# RT @realDonaldTrump: Corrupt politician Joe Biden makes Crooked Hillary look like an amateur!
# RT @RealJamesWoods: Hunter Biden's Hard Drive Links Joe Biden to Foreign Lobbying Operations https://t.co/5cxySmifut
# @brianbeutler Biden can revoke Trump’s clearance, can’t he?
# RT @daveweigel: @HeerJeet The president’s son joked about Biden being a pedophile, a Fox News host says Biden’s son might have child porn,…
# @funny_mo_fekir @adamhousley @raidermike5569 Yes set up for Biden , DOJ and the FBI. The American ppl will finally see they are all corrupt
# RT @thebradfordfile: Joe Biden needs to register as a foreign agent representing Beijing.
# RT @KyleKulinski: You made $73 million from foreign investors as president and Jared &amp; Ivanka made $135 million in 2018 alone. Biden is def…
# RT @EmmaRincon: Les presento a Kristen Welker, ella será la moderadora (imparcial) del último debate presidencial entre Trump y Biden el 22…
# RT @davidmweissman: The Trump campaign attacks Hillary Clinton and her emails, now they’re Joe and Hunter Biden’s emails. Everything I’ve l…
# RT @magnitsky: Part 1: During Hunter Biden’s time on the Burisma Holdings board, Burisma’s Crimean oil &amp; natural gas subsidiary KrymTopEner…
# RT @thejtlewis: Donald Trump got rich running his business.
#
# Joe Biden got rich ruining our government.
# RT @UniteCountryPAC: “I’m running as a proud Democrat, but I’m going to be an American president. I’m going to take care of those who voted…

# %%
########### build library for stopwrods, positive words, and negative words

# punctuation from string library
import re
from collections import Counter

with open(cur_dir + 'stopwords.txt') as inputfile:
    for line in inputfile:
        stopwords = filter(None, (line.rstrip() for line in inputfile))

#stop = open(cur_dir + "stopwords.txt").read()
#stopwords = stop.split('\n')

 # positive words from: http://www.unc.edu/~ncaren/haphazard/positive.txt
positive_words = open(cur_dir + 'positive.txt').read()
positive = positive_words.split('\n')

# negative words from: http://www.unc.edu/~ncaren/haphazard/negative.txt
negative_words = open(cur_dir + 'negative.txt').read()
negative = negative_words.split('\n')

########### function for preprocessing
#import nltk
from string import punctuation

def turn_to_words(input_list):
    text = ' '.join(input_list)  # merge list of strings into a single big string, separated by ' '
    
    for p in list(punctuation): # remove punctuation
        text = text.replace(p,' ')
        
    #for p in list(stopwords): # remove stopwords
    #    text = text.replace(p,' ')
    
    text = text.lower() # to lowercase
    text = text.split() # turn into words
    
    return text

# %%
#for tweet in Trump_tweets:

mylist = []
for tweet in trump_tweets:
    mylist.append(tweet.text) # create a list of tweets (string)

words = turn_to_words(mylist) # create list of words out of all the tweets (remove punctuation + lowercase)

sentiment = [];
for word in words:
    if word in list(positive) or word in list(negative):
        sentiment.append(word)  # create a list of sentiment words

#print(sentiment)

sentiment_counts = Counter(sentiment)
ten_common = sentiment_counts.most_common(10) # 10 most common sentiment words
                                                                                                                

ten_common_list = []
for i in ten_common:
    ten_common_list.append(i[0]) # extract words from each tuple, and make them into a list

pos = 0
neg = 0
for word in ten_common_list:
    if word in positive:
        pos = pos + 1
    if word in negative:
        neg = neg + 1
print(ten_common)
print ("TRUMP: positive words: " + str(pos) + " negative words: " + str(neg))
x=(pos-neg)/10.0
print ("TRUMP's Average Sentiment Value: " + str(float("{0:.2f}".format(x))))
# Out:
# [('will', 7), ('just', 6), ('against', 5), ('pro', 3), ('worst', 3), ('significant', 3), ('upset', 3), ('close', 3), ('leading', 3), ('panic', 3)]
# TRUMP: positive words: 5 negative words: 5
# TRUMP's Average Sentiment Value: 0.0

# %%
#for tweet in Biden_tweets:

mylist = []
for tweet in biden_tweets:
    mylist.append(tweet.text) # create a list of tweets (string)

words = turn_to_words(mylist) # create list of words out of all the tweets (remove punctuation + lowercase)

sentiment = [];
for word in words:
    if word in list(positive) or word in list(negative):
        sentiment.append(word)  # create a list of sentiment words

#print(sentiment)

sentiment_counts = Counter(sentiment)
ten_common = sentiment_counts.most_common(10) # 10 most common sentiment words


ten_common_list = []
for i in ten_common:
    ten_common_list.append(i[0]) # extract words from each tuple, and make them into a list

pos = 0
neg = 0
for word in ten_common_list:
    if word in positive:
        pos = pos + 1
    if word in negative:
        neg = neg + 1
print(ten_common)
print ("BIDEN: positive words: " + str(pos) + " negative words: " + str(neg))
x=(pos-neg)/10.0
print ("BIDEN's Average Sentiment Value: " + str(float("{0:.2f}".format(x))))
# Out:
# [('corrupt', 9), ('crooked', 8), ('just', 4), ('down', 2), ('crook', 2), ('friends', 2), ('need', 2), ('will', 2), ('hard', 2), ('rich', 2)]
# BIDEN: positive words: 4 negative words: 6
# BIDEN's Average Sentiment Value: -0.2
