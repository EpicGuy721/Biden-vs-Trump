# %%
################################# input parameters
cur_dir = 'C:/Users/EpicG/Documents/Python Scripts/webscraping/'
number_tweets = 2000
#################################

# %%
import os
# Use tweepy api for authentication 
from configparser import ConfigParser
config = ConfigParser()
config.read('C:/Users/EpicG/Documents/Python Scripts/webscraping/cfg/sample.cfg')
# Out:
# ['C:/Users/EpicG/Documents/Python Scripts/webscraping/cfg/sample.cfg']

# %%
# Create an Authentication Handler
import tweepy
auth = tweepy.OAuthHandler(config.get('twitter', 'consumer_key'), config.get('twitter', 'consumer_secret'))
auth.set_access_token(config.get('twitter','access_token'), config.get('twitter','access_token_secret'))
api = tweepy.API(auth)

# %%
# search tweets for keywords
trump_tweets = api.search(q="Trump", count=number_tweets, show_user=False)
biden_tweets = api.search(q="Biden",count=number_tweets, show_user=False)

# %%
for tweet in trump_tweets:
    print(tweet.text)
# Out:
# RT @Notyour28981739: I thought the BLM protests were about police brutality. Since when did they turn on and decide to protest their fellow…
# RT @rjoseph7777: ‘Incompetent moron’ Chuck Todd ripped for letting Trump official claim Democrats want more COVID-19 deaths https://t.co/jy…
# RT @RBReich: Pay attention. Donald Trump is using the pandemic as cover to defund Social Security and Medicare in the middle of the worst e…
# RT @SenSherrodBrown: What Trump’s selling you: A fake tax cut that has to be paid back.
#
# What Trump’s ACTUALLY doing: Draining your Social…
# RT @alexisbrileyy: Massive Trump Boat Parade at Atlantic Beach @realDonaldTrump https://t.co/qM8C3gSBoh
# @PeptoState i'm predicting a second term for trump, an airborne syphilis pandemic, and a gorilla will get shot.
# RT @OnceVirginian: @JoeBiden What's destroyed the U.S postal service is called the internet, the more we use it to pay Bill's and contact o…
# RT @JoshuaPotash: Reminder that Mitch McConnell is burying election security legislation. It’s not just Trump. It’s a concerted GOP effort…
# RT @SenWarren: If Donald Trump cared about helping Americans, he would have demanded @SenateMajLdr McConnell start negotiating as soon as t…
# Since 82% of Americans favor a national mask mandate according a recent poll, it’s foolish for the AZ Republicans t… https://t.co/5YbxGHMDdu
# RT @JoshuaPotash: Reminder that Mitch McConnell is burying election security legislation. It’s not just Trump. It’s a concerted GOP effort…
# RT @MAGAPATRIOT_TGM: All of the Executive Order’s Obama signed, many of them questionable. And his EO’s were constitutional but Trump’s are…
# @Dantwittee @DaraSings @RepJoeKennedy You mean like Trump telling people if he gets re elected he will consider the… https://t.co/XTOKBT92rf
# RT @JoeBiden: Every single eligible American should have the opportunity to vote-by-mail this November. If it's good enough for Donald Trum…
# RT @ambertamblyn: This audio is from my husband @davidcrosss 2016 standup special, Making America Great Again on @netflix . If you haven't…
# @andrewcuomo and the DEMOCRATS are AGAINST Trump’s Executive Order that will provide financial assistance to millio… https://t.co/wa9pds4FKC
# RT @BillKristol: “Maybe it’s just me, but Trump delaying prescriptions for veterans in order to help win an election seems like a winning m…
# @CBSNews You forgot the qualifier trump “thinks” he signed measures meant to provide economic aid...he has absolute… https://t.co/DKlvorNhDZ
# RT @jonfavs: Donald Trump just unilaterally cut Social Security and your unemployment benefits.
with open(cur_dir + 'stopwords.txt') as inputfile:
    for line in inputfile:
        stopwords = filter(None, (line.rstrip() for line in inputfile))

#stop = open(cur_dir + "stopwords.txt").read()
#stopwords = stop.split('\n')

 # positive words from: http://www.unc.edu/~ncaren/haphazard/positive.txt
positive_words = open(cur_dir + 'positive.txt').read()
positive = positive_words.split('\n')

# negative words from: http://www.unc.edu/~ncaren/haphazard/negative.txt
negative_words = open(cur_dir + 'negative.txt').read()
negative = negative_words.split('\n')

########### function for preprocessing
#import nltk
from string import punctuation

def turn_to_words(input_list):
    text = ' '.join(input_list)  # merge list of strings into a single big string, separated by ' '
    
    for p in list(punctuation): # remove punctuation
        text = text.replace(p,' ')
        
    #for p in list(stopwords): # remove stopwords
    #    text = text.replace(p,' ')
    
    text = text.lower() # to lowercase
    text = text.split() # turn into words
    
    return text

# %%
#for tweet in Trump_tweets:

mylist = []
for tweet in trump_tweets:
    mylist.append(tweet.text) # create a list of tweets (string)

words = turn_to_words(mylist) # create list of words out of all the tweets (remove punctuation + lowercase)

sentiment = [];
for word in words:
    if word in list(positive) or word in list(negative):
        sentiment.append(word)  # create a list of sentiment words

#print(sentiment)

sentiment_counts = Counter(sentiment)
ten_common = sentiment_counts.most_common(10) # 10 most common sentiment words
                                                                                                                

ten_common_list = []
for i in ten_common:
    ten_common_list.append(i[0]) # extract words from each tuple, and make them into a list

pos = 0
neg = 0
for word in ten_common_list:
    if word in positive:
        pos = pos + 1
    if word in negative:
        neg = neg + 1
print(ten_common)
print ("TRUMP: positive words: " + str(pos) + " negative words: " + str(neg))
x=(pos-neg)/10.0
print ("TRUMP's Average Sentiment Value: " + str(float("{0:.2f}".format(x))))
# Out:
# [('security', 14), ('just', 10), ('will', 7), ('white', 4), ('against', 3), ('hope', 3), ('avalanche', 3), ('threat', 3), ('worst', 2), ('fake', 2)]
# TRUMP: positive words: 5 negative words: 5
# TRUMP's Average Sentiment Value: 0.0

# %%
#for tweet in Biden_tweets:

mylist = []
for tweet in biden_tweets:
    mylist.append(tweet.text) # create a list of tweets (string)

words = turn_to_words(mylist) # create list of words out of all the tweets (remove punctuation + lowercase)

sentiment = [];
for word in words:
    if word in list(positive) or word in list(negative):
        sentiment.append(word)  # create a list of sentiment words

#print(sentiment)

sentiment_counts = Counter(sentiment)
ten_common = sentiment_counts.most_common(10) # 10 most common sentiment words


ten_common_list = []
for i in ten_common:
    ten_common_list.append(i[0]) # extract words from each tuple, and make them into a list

pos = 0
neg = 0
for word in ten_common_list:
    if word in positive:
        pos = pos + 1
    if word in negative:
        neg = neg + 1
print(ten_common)
print ("BIDEN: positive words: " + str(pos) + " negative words: " + str(neg))
x=(pos-neg)/10.0
print ("BIDEN's Average Sentiment Value: " + str(float("{0:.2f}".format(x))))
# Out:
# [('will', 9), ('great', 4), ('just', 4), ('security', 4), ('stellar', 4), ('upset', 3), ('hurt', 3), ('approval', 2), ('black', 2), ('better', 2)]
# BIDEN: positive words: 7 negative words: 3
# BIDEN's Average Sentiment Value: 0.4
